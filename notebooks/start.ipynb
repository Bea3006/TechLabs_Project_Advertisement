# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read Textdata

# %%
data = pd.read_csv("D:\Influencer_Projekt\influencers.txt", sep='\t')

# %%
data.head(10)
# Out:
#                                             Username Category  #Followers  \
# 0  ==============================================...      NaN         NaN
# 1                                        makeupbynvs   beauty      1432.0
# 2                                  jaquelinevandoski   beauty    137600.0
# 3                                      anisaartistry   beauty     64644.0
# 4                                  rubina_muartistry   beauty    496406.0
# 5                                        beautyxabbi   beauty      2050.0
# 6                                        vemakeup713   beauty     99226.0
# 7                                       glaminfusion   beauty      4717.0
# 8                                      paisleymattes   beauty    108193.0
# 9                                      meghanmakeup_   beauty      1430.0
#
#    #Followees  #Posts
# 0         NaN     NaN
# 1      1089.0   363.0
# 2       548.0   569.0
# 3       289.0   391.0
# 4       742.0   887.0
# 5      1423.0   751.0
# 6       613.0   536.0
# 7       506.0   287.0
# 8      1240.0  1008.0
# 9      1160.0   284.0

# %% [markdown]
# ### How many catagories do we have?

# %%
data['Category'].value_counts()
# Out:
# fashion        11911
# other           5720
# travel          4210
# family          4070
# food            3565
# beauty          1542
# interior        1195
# fitness         1133
# pet              587
# fasion             1
# fashion 0.5        1
# Name: Category, dtype: int64

# %% [markdown]
# ### just a test

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33936 entries, 0 to 33935
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Username    33936 non-null  object
#  1   Category    33935 non-null  object
#  2   #Followers  33935 non-null  float64
#  3   #Followees  33935 non-null  float64
#  4   #Posts      33935 non-null  float64
# dtypes: float64(3), object(2)
# memory usage: 1.3+ MB

# %%
data.head()
# Out:
#                                             Username Category  #Followers  \
# 0  ==============================================...      NaN         NaN
# 1                                        makeupbynvs   beauty      1432.0
# 2                                  jaquelinevandoski   beauty    137600.0
# 3                                      anisaartistry   beauty     64644.0
# 4                                  rubina_muartistry   beauty    496406.0
#
#    #Followees  #Posts
# 0         NaN     NaN
# 1      1089.0   363.0
# 2       548.0   569.0
# 3       289.0   391.0
# 4       742.0   887.0

# %% [markdown]
# ## Import 500 Posts

# %%
import pandas as pd
import glob
import json
import os

# %%
path = r"D:\Influencer_Projekt\posts_info\500_Posts"
os.chdir(path)

# %%
# list all files from folder
file_list = []
for file in glob.glob("*.info"):
    file_list.append(file)

# %%
post_table = pd.DataFrame(columns=["shortcode", "influencer_profile", "nb_comments", "nb_likes"])

# loop to load all files
for i in range(0, len(file_list)):
    
    print(i)
    
    # Empty temporary table
    temp_table = pd.DataFrame(columns=["shortcode", "influencer_profile", "nb_comments", "nb_likes"])

    data_temp = json.load(open(file_list[i]))
    
    # Shortcode
    temp_table.at[0, "shortcode"] = data_temp["shortcode"]
    
    # Influencer Profile
    temp_table.at[0, "influencer_profile"]  = data_temp["owner"]["username"]
    
    # Number of comments
    try: 
        temp_table.at[0, "nb_comments"] = data_temp["edge_media_preview_comment"]["count"]
    except: 
        temp_table.at[0, "nb_comments"] = data_temp["edge_media_to_comment"]["count"]
    
    # Number of likes
    try:
        temp_table.at[0, "nb_likes"] = data_temp["edge_media_preview_like"]["count"]
    except:
        temp_table.at[0, "nb_likes"] = data_temp["edge_media_to_like"]["count"]        

    
    print(temp_table)
    
    post_table = post_table.append(temp_table)
# Out:
# 0
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtVTRNaD9uF    zeldawasawriter          10      475
# 1
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkSQoFQHQuj              zelia          30     4228
# 2
#      shortcode influencer_profile nb_comments nb_likes
# 0  Btzi8lklZL3              zelia          15     2355
# 3
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bn1FtgsFY4W        zenandspice           5       60
# 4
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bp3NpIKlgb3        zenandspice           2       30
# 5
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgeZ3bdHjZ7      zenassuitcase          27      400
# 6
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoL0CjNFYtV      zenassuitcase          50      549
# 7
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuqXLATFiH0      zenassuitcase          42      438
# 8
#      shortcode influencer_profile nb_comments nb_likes
# 0  BezIqXXDb_D          zenevesze          29      665
# 9
#      shortcode influencer_profile nb_comments nb_likes
# 0  BFExaycOh4N           zerkaahd         295    42157
# 10
#     shortcode influencer_profile nb_comments nb_likes
# 0  0GCRefOh3M           zerkaahd         330    27169
# 11
#      shortcode influencer_profile nb_comments nb_likes
# 0  BVF7f5vlJ5Q       zerowasteguy           7      200
# 12
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bs_hoBPlaJT       zerowasteguy           8      477
# 13
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrwD4R1gna1     zestfulkitchen          12      361
# 14
#      shortcode influencer_profile nb_comments nb_likes
# 0  BocBZXAlZGF        zestmylemon         170     9097
# 15
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bo4JYHHlZVS        zestmylemon         150    10277
# 16
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsLyrMVl2bK        zestmylemon         254    13688
# 17
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bh6QOhKnZJR         zetema_srl           1      145
# 18
#      shortcode influencer_profile nb_comments nb_likes
# 0  BogTJILnTIw         zetema_srl           0       62
# 19
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bfw8mHgFR-o            zevyjoy          45     1329
# 20
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnWxja1lxiG            zevyjoy          26      818
# 21
#      shortcode influencer_profile nb_comments nb_likes
# 0  Buj3qcLBP2j            zevyjoy          43      891
# 22
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhyWOcxH9t1         zeworkroom           0      128
# 23
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnxsvTqh3oB       zezivotazeny           0      129
# 24
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrW2b7CFmJd       zezivotazeny           4      115
# 25
#      shortcode influencer_profile nb_comments nb_likes
# 0  BspWEL_lKil       zezivotazeny          15      167
# 26
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpkP8uYHcKJ    zhimino_wedding          58     1816
# 27
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bsqiuh7n9TX    zhimino_wedding         225     6236
# 28
#      shortcode influencer_profile nb_comments nb_likes
# 0  BwKeEbJnL7o    zhimino_wedding          87     7246
# 29
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtuoFMVAGJE            zhocare           0       30
# 30
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsrEb8nHn6l            zhureta         214      648
# 31
#      shortcode influencer_profile nb_comments nb_likes
# 0  BY6f-EQHsqk            zianana           3       69
# 32
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bk5WidjFr1U   ziggymackjohnson          16      899
# 33
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpzVAhxHy2f          zigzagmom          90      943
# 34
#      shortcode influencer_profile nb_comments nb_likes
# 0  BdhVszhHQ05       zigzagzurich           1      171
# 35
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrNuX3wgc-Q       zigzagzurich           0      147
# 36
#      shortcode influencer_profile nb_comments nb_likes
# 0  BYscPP4lszL            ziiarch          21     2320
# 37
#      shortcode              influencer_profile nb_comments nb_likes
# 0  BnrvVECl5wD  zilmara_mega_fa_simone_simaria           2      125
# 38
#      shortcode              influencer_profile nb_comments nb_likes
# 0  Bs8TjJ6he65  zilmara_mega_fa_simone_simaria           0       54
# 39
#      shortcode influencer_profile nb_comments nb_likes
# 0  BiImSH_nz5y         zimmysnook          43      651
# 40
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bnuke2fH-PH         zimmysnook          49      636
# 41
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrtlSMShump         zimmysnook          45      544
# 42
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmS_-0Cg_wN    zinafashionvibe           5      408
# 43
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoPDh83ghmE    zinafashionvibe          78     3402
# 44
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtD0h3aAAgD    zinafashionvibe          22      854
# 45
#      shortcode influencer_profile nb_comments nb_likes
# 0  BajuotZBSYZ         zipporahb_          56      980
# 46
#      shortcode influencer_profile nb_comments nb_likes
# 0  BbjxdkVBlnC         zipporahb_          45      945
# 47
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpgQGNBAIe-         zipporahb_           6      511
# 48
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bt5B7ZPATzu         zipporahb_          11      904
# 49
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bo2LTV5jdpc          zipporahs           3      398
# 50
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BKS-PuuDok2  zirakeecharlesyanar           2      112
# 51
#      shortcode   influencer_profile nb_comments nb_likes
# 0  Biaeg00n8wq  zirakeecharlesyanar           4       78
# 52
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgUTaiNHKMv         zitamaleki           5      410
# 53
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpZf5londIJ         zitamaleki          26      794
# 54
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bn1K7u3BtGX  zitateundsprueche          58     6339
# 55
#      shortcode influencer_profile nb_comments nb_likes
# 0  BenyV_XBfu5       zivajaversek          15      187
# 56
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnD-5wshZvT        zivotpo30ce           8      383
# 57
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZLOtpFlJEB        zizotshwete         180    17307
# 58
#      shortcode influencer_profile nb_comments nb_likes
# 0  BUtzVWVBqi4   zlinfilmfestival           0       71
# 59
#      shortcode influencer_profile nb_comments nb_likes
# 0  BSGvtwQha5T        zockerstuff          27     2379
# 60
#      shortcode influencer_profile nb_comments nb_likes
# 0  BTJwYHSBHE9        zockerstuff          19      523
# 61
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bw69YW4FXFE          zodiac709          95     6239
# 62
#      shortcode influencer_profile nb_comments nb_likes
# 0  BxW8GjnFeFp          zodiac709          74     6469
# 63
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bs297aEgCd_         zodiacmore           6     3724
# 64
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BvelYi7go_M  zodiacrelationship          49     2384
# 65
#      shortcode influencer_profile nb_comments nb_likes
# 0  BivRDHXhBpG            zodieac          18      861
# 66
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bn1md5CgJzP     zoe.ballerina1          45     4247
# 67
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl_Q5GTA9x1   zoeelizabethblog          16      512
# 68
#      shortcode influencer_profile nb_comments nb_likes
# 0  BniqLDPg4sV   zoeelizabethblog           3      423
# 69
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuW4Wh2F-6X          zoefit_uk          58      521
# 70
#      shortcode influencer_profile nb_comments nb_likes
# 0  BurihTylVJE          zoefit_uk          93      713
# 71
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXQ5h30gXWb    zoegriffinphoto          19      213
# 72
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bf_miMmAX3y    zoegriffinphoto           9      230
# 73
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjDIyRPBQoA    zoegriffinphoto          26      251
# 74
#      shortcode influencer_profile nb_comments nb_likes
# 0  BX0IKamhgwf         zoehardman           2      192
# 75
#      shortcode influencer_profile nb_comments nb_likes
# 0  BdhH6ufh0VC         zoehardman           4      636
# 76
#      shortcode influencer_profile nb_comments nb_likes
# 0  BN4vd75A9HE   zoein_wonderland           5     1830
# 77
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqumkA6la-o             zoelaz         117    11628
# 78
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br49YZQDD0X             zoella          93    28830
# 79
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjKMP00h1Lc        zoelondondj           9     1026
# 80
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bqc_nPqHsPR        zoelondondj          37     2633
# 81
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXXUWuIgUWL         zoenewlove           9      128
# 82
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bozart_nkW0        zoepastelle         182    11179
# 83
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtlvqNJhGKG        zoepastelle          83     8967
# 84
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmtOdp7jwHC          zoeyivory           6     1189
# 85
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsGOlsyn_3l         zoeylou_sw          13     1245
# 86
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmluspkjMBq       zoeymusic777          16      461
# 87
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvT6E0IHE7y          zombijana          10     2265
# 88
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXnsyivFmbO             zoozel          70     1081
# 89
#      shortcode       influencer_profile nb_comments nb_likes
# 0  BvGZRMfF73Z  zorainsstudioandacademy          20     1306
# 90
#      shortcode       influencer_profile nb_comments nb_likes
# 0  BvTFwptFarI  zorainsstudioandacademy           0      629
# 91
#      shortcode influencer_profile nb_comments nb_likes
# 0  Blk2r_2hO2u           zorannah         130    30465
# 92
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bs7yYNJgcoZ           zorannah          68    28146
# 93
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bg4Ffl7HMrI      zorapalkovics           4     1550
# 94
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqSsERABmEI      zorapalkovics           3     2649
# 95
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BryblidFyyQ  zorro.the.huskywolf          10      100
# 96
#      shortcode influencer_profile nb_comments nb_likes
# 0  Be3bSBxA2Fe          zosiarome          16      264
# 97
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoXCJx4nMxv          zosiarome          12      244
# 98
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgYzhpJhIr7             zosuen           8     2126
# 99
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bj4w4bHDBML             zosuen           4     1261
# 100
#      shortcode influencer_profile nb_comments nb_likes
# 0  BdInAvDhis-       zozinette127          74      536
# 101
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfJLq83BpeF       zozinette127          98      597
# 102
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br0sSlWhwvt       zozinette127          38      356
# 103
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZ0MVx3hlBt            zozoewi           2       74
# 104
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bi6oKtGHEFO           zozo_mum           7      835
# 105
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpHxfrXBUIZ           zozo_mum           8      613
# 106
#      shortcode influencer_profile nb_comments nb_likes
# 0  BieMriyFCEu        zr.omar.uae           2       30
# 107
#      shortcode influencer_profile nb_comments nb_likes
# 0  Brxw9ZgAbDD        zr.omar.uae           0        6
# 108
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl0PEkmAca9      zsanettkorosi           5      130
# 109
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZohR96FC3Y        zsofiavoros          17      639
# 110
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuWzMCoFHSo         zsuzsubell          57     3930
# 111
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bjh4ZqgF7ee  zucker.stueckchen          40      386
# 112
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkejslLFHQp  zucker.stueckchen          52      424
# 113
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpwvhdKFfVC   zulian_calzature           0       36
# 114
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqB8HWJHFNG        zumbacarbis           3       74
# 115
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsZYKown4Vh        zumbacarbis           1       41
# 116
#      shortcode influencer_profile nb_comments nb_likes
# 0  BYR-JBZAnCs       zuneraserena          60     3146
# 117
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BlHuRUxFSC6  zurich.influencers          39      262
# 118
#      shortcode  influencer_profile nb_comments nb_likes
# 0  Bof-c1jgeDm  zurich.influencers         103     1280
# 119
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkTD9CUl-ww  zurichfoodadvisor           6      216
# 120
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bnog-bdlW0J  zurichfoodadvisor          18      275
# 121
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZmQSDtFw-M           zurihall          18     1866
# 122
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bjgsh0HHvsV       zusinterieur           9      415
# 123
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnNyjV_ikFk       zusinterieur          17      588
# 124
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bjcre-DANl3      zuzanastraska           7      988
# 125
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bjl0mspAEA5      zuzanastraska           8     1205
# 126
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkPK1QeAEZQ      zuzanastraska           4     1800
# 127
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bdq3vBvAJGA         zweigyossi           1       36
# 128
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlIpmsMHVxY         zweigyossi           5       85
# 129
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl8_vykH_2k         zweigyossi           0       57
# 130
#      shortcode influencer_profile nb_comments nb_likes
# 0  BcFLHDqFrjM          zwithlove           9       98
# 131
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bg0h2JHFOhG          zwithlove           7      167
# 132
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsBOF09hHCx          zwithlove           5      114
# 133
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrGIvGtntfp             zyda16           2       70
# 134
#      shortcode influencer_profile nb_comments nb_likes
# 0  BcSkzFaFTSt         zyndl_lala           1      363
# 135
#     shortcode influencer_profile nb_comments nb_likes
# 0  tWOhJXBalF        _addiejones           6      158
# 136
#      shortcode influencer_profile nb_comments nb_likes
# 0  BcCl_J0lU3B    _agneslifestyle          74     1905
# 137
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkUd2_9lDSS      _alexdavidson          19      505
# 138
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuQKd2pgjwY      _alexdavidson          14      589
# 139
#      shortcode influencer_profile nb_comments nb_likes
# 0  BK4GDwDAZEi       _alexisevans           7       65
# 140
#      shortcode influencer_profile nb_comments nb_likes
# 0  BQ_ifQSBiLh       _alexisevans           3      102
# 141
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjU9qBDnECi       _alexisevans           2      135
# 142
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjscI9UHgYy       _alexisevans           4      133
# 143
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjzCbnihqtu     _alisa_martini          57      458
# 144
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bj1mZA3BZs-     _alisa_martini          15      262
# 145
#      shortcode influencer_profile nb_comments nb_likes
# 0  Brf--8vlWAe     _alisa_martini          35      257
# 146
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bfbwpi7jrOH       _allsmilesxo          27     1152
# 147
#      shortcode influencer_profile nb_comments nb_likes
# 0  BcQB0e1DS0v          _alussier           3      702
# 148
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqPujWHhazN          _alussier           7      444
# 149
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhDZ4kHFmCM         _alyssamay          74     2500
# 150
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhfyoweFyoS         _alyssamay         101     4160
# 151
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bc5W4poHbDO      _ambergordon_          17      182
# 152
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bc71dEKnjDX      _ambergordon_           8      248
# 153
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bd5lO2iAoBf      _ambergordon_           6      307
# 154
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgebZVPnXRV      _ambergordon_           8      246
# 155
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpFQiQwlf8b         _amimanera           3       49
# 156
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkcjIUoDUse     _amuralhunter_          15      130
# 157
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgO3y_8HauH       _andrea_snow          38      647
# 158
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bn5PueOlr3y       _annamelissa          13      291
# 159
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjUdfs6hIUF        _annandrea_          10      464
# 160
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bm0fAU1B5rK        _annandrea_          17      634
# 161
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZLDYmPFnNE          _anutka__          25      974
# 162
#      shortcode influencer_profile nb_comments nb_likes
# 0  BbbWAjmDMsr          _anutka__          40     1247
# 163
#      shortcode influencer_profile nb_comments nb_likes
# 0  BibCkXmDRdp          _anutka__          20     1405
# 164
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpAFlIBi7nV         _arezoo.f_         291     8349
# 165
#      shortcode influencer_profile nb_comments nb_likes
# 0  Btwh5ldhFXO      _ariadnediaz_           2      305
# 166
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvZ-jPFA4lV      _ariadnediaz_           3      901
# 167
#      shortcode influencer_profile nb_comments nb_likes
# 0  BLRUxbuAkon           _artacha          18     1075
# 168
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bi17JrunwW_       _ashlee.ann_          32      992
# 169
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl1Ct8kH3Po       _ashlee.ann_          24     1066
# 170
#      shortcode influencer_profile nb_comments nb_likes
# 0  BcJHv19nF6t    _ashtonlocklear          39    10695
# 171
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgwZ098AyBT   _aubreanascurlss          22      658
# 172
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoIBtuOBOI7   _aubreanascurlss          31      947
# 173
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlVTTR0DRmf             _aurra           9      537
# 174
#      shortcode influencer_profile nb_comments nb_likes
# 0  BwCczG8nCb1             _aurra           1      211
# 175
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bja0envFSRE     _austinengland           3      555
# 176
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bie8lBDleh9            _ayomoe           2       21
# 177
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsEHnXBBL15            _ayomoe           2       32
# 178
#      shortcode influencer_profile nb_comments nb_likes
# 0  BiSBVlZFDGu            _azrak_          89      373
# 179
#      shortcode influencer_profile nb_comments nb_likes
# 0  BklrydEFhHK            _azrak_          66      335
# 180
#      shortcode influencer_profile nb_comments nb_likes
# 0  BavTB7glNwV    thepedalproject           6      168
# 181
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BupOFeTljtI  _baileythecavoodle          12      405
# 182
#      shortcode      influencer_profile nb_comments nb_likes
# 0  BmkddNvDwyS  _beautiful_homeliving_          22      236
# 183
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgItHOhF_vn       _beautykath_           2      148
# 184
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlpXAMjDiUf       _beautykath_           6      242
# 185
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bqc4ZWeAgIZ       _beautykath_           4      209
# 186
#      shortcode influencer_profile nb_comments nb_likes
# 0  Ba7xl15B6t-      _beckykimball          79     1214
# 187
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bt2pn3ohRhl         _berrykid_          22     1369
# 188
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrKtx3clrBv       _blondschopf         133     1102
# 189
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZ125BGH2gc    _brokeandhungry          92      708
# 190
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkntJHvnpMM    _brokeandhungry          66      672
# 191
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl35fb_nLii    _brokeandhungry          79      907
# 192
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnboaOTjhlM   _brunnahcarvalho           3       93
# 193
#      shortcode influencer_profile nb_comments nb_likes
# 0  BbcJPAlj7L9           _bubsbee          52     2266
# 194
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkN1FSpF9QI          _by.chloe          22      272
# 195
#      shortcode influencer_profile nb_comments nb_likes
# 0  BeIHD2IFWVx          _bysteffi           1       70
# 196
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bi8-OVjFR9P          _bysteffi           3       92
# 197
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpE5WaOFhFy      _callmemariss           3       88
# 198
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpHTG01FSov      _callmemariss           1       91
# 199
#      shortcode influencer_profile nb_comments nb_likes
# 0  BggqzC_FK8C     _callmesparkle          22     1364
# 200
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BciWYfVlrwt  _capturingmamahood           3      165
# 201
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BkvC0V0BHuS  _capturingmamahood           0       43
# 202
#      shortcode influencer_profile nb_comments nb_likes
# 0  BdO2S3YAgND        _caraharper          15      947
# 203
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrqkUS4n3SE        _caraharper          13     1221
# 204
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmOaxViDNy3      _carlabeautyy           1       56
# 205
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlFsujNnQQF         _caro.fit_           2      107
# 206
#      shortcode influencer_profile nb_comments nb_likes
# 0  BOxaMR4gNu5       _catpeterson           3      289
# 207
#      shortcode influencer_profile nb_comments nb_likes
# 0  BW7wo1Jlddu        _celinamitc           3      189
# 208
#      shortcode influencer_profile nb_comments nb_likes
# 0  Btp1hzcgEEw         _celine_be          21      683
# 209
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhGwj4ijNWg    _charlesoliver_          27      905
# 210
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkM5SOpnph4    _charlesoliver_          26      657
# 211
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BisUNVznIfw  _heartsofhappiness_          21      538
# 212
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfR0bWqBiaK          _chellita           4      423
# 213
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjazrkwlS3P          _chellita          43      858
# 214
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bm7OJlSlz3W          _chellita           8      420
# 215
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmmlOCkH0fq       _chloechloee          10     1931
# 216
#      shortcode influencer_profile nb_comments nb_likes
# 0  BosEQY9HZnQ       _chloechloee           9     1274
# 217
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bcu-DVGHLZf               _cm0           0       50
# 218
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bdh6anPn7s1               _cm0           3       75
# 219
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfrL9jvFPT-    _creativemommy_          41     1177
# 220
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bm4edAgleBX    _creativemommy_          39      983
# 221
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bo4hlSkCElS       _dailyapple_          19      386
# 222
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BlLyh8QAOQv  _dailydoseofluxury          15      170
# 223
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BljsX69gvVv  _dailydoseofluxury          90      402
# 224
#      shortcode influencer_profile nb_comments nb_likes
# 0  BVKcteuhUhN       _danielglick           4      284
# 225
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bs4qfxuAyhI       _danielglick           3      270
# 226
#      shortcode influencer_profile nb_comments nb_likes
# 0  BK8IwAIhHmB    _danielmontero_           3     1900
# 227
#      shortcode influencer_profile nb_comments nb_likes
# 0  Besj-ENj64B    _davidecorsini_           3     2579
# 228
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfS-XogAkN3    _davidecorsini_          11     2824
# 229
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhaG0xyH1wi           _dcarrie           2       72
# 230
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfaOkHklc2P    _denniskoehler_           2      630
# 231
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqVRXokAG_u        _eatandlove          27      501
# 232
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgbJcfhh3b4        _eazybreezy           1       84
# 233
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bcs8CwDBLiz          _effifit_          17       45
# 234
#      shortcode influencer_profile nb_comments nb_likes
# 0  BppeF0AAHQK     _ellenbrewster           5      180
# 235
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bq4NyjWgNKB     _ellenbrewster           4      160
# 236
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bq7FdwBAarB     _ellenbrewster           4      202
# 237
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bu0iTWZAlMz     _ellenbrewster           0      136
# 238
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmFKl-TBklj        _ellifrench          12       81
# 239
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bt6O40QAFO2        _ellifrench           4       50
# 240
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkgJnswFjFP        _elodypetit          36    12411
# 241
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqpnqmQASks         _elyunior_           3      256
# 242
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br9o89Wh384          _emilieaa          13     1057
# 243
#      shortcode influencer_profile nb_comments nb_likes
# 0  BOYDZFhjsO_         _emilyhuff          42     8422
# 244
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgP0YbShlTm         _emilyhuff          42    12711
# 245
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsjH0iVn1xV         _emilyhuff         135     7914
# 246
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvcOR8IH0ex         _emilyhuff          56     9991
# 247
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuIv1t3FXCZ            _enabla          22     2401
# 248
#      shortcode influencer_profile nb_comments nb_likes
# 0  BU8o53oA5JU    _ericaaaaaaaaa_          37      572
# 249
#      shortcode influencer_profile nb_comments nb_likes
# 0  BX8DTj9Aksu    _ericaaaaaaaaa_         110     1316
# 250
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bp-kV9OFaJ8    _everydayariana          73      204
# 251
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtZHpZkAhS0    _everydayariana          18      115
# 252
#      shortcode       influencer_profile nb_comments nb_likes
# 0  BursfhyhJBe  _famigliaferragnilucia_           0      133
# 253
#      shortcode       influencer_profile nb_comments nb_likes
# 0  Bu12L4fhQ6L  _famigliaferragnilucia_           0       62
# 254
#      shortcode       influencer_profile nb_comments nb_likes
# 0  BvND97jFmhY  _famigliaferragnilucia_           3      143
# 255
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BpmyqvSg-7S  _fashionablynoble_          95     4163
# 256
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlJH55hnvyL          _fedesavi         178     1171
# 257
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoqzmrBHrsC          _fedesavi         398     2065
# 258
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfMiEEWg8Bf      _fit.bashley_           0       29
# 259
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bh2VOM_l_eD      _fit.bashley_           0       51
# 260
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bh6rdq4FYSb      _fit.bashley_           1       48
# 261
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkDHQZBFDjL      _fit.bashley_           6       89
# 262
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlBcnWKFw_b      _fit.bashley_           3       46
# 263
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bm7NuYyghDd      _fit.bashley_           7       58
# 264
#      shortcode influencer_profile nb_comments nb_likes
# 0  Blw40iPFJyu      _foxandcoffee           5       81
# 265
#      shortcode influencer_profile nb_comments nb_likes
# 0  BQxnI6VB_Jr       _francescodi          34     1035
# 266
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlpyeYeAeMT           _fullout           2       87
# 267
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bnqlhf4Ar22           _fullout           2      152
# 268
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpVM5ZHFh00           _fullout           1       81
# 269
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bu4Js8rlOG_           _fullout           0       65
# 270
#      shortcode influencer_profile nb_comments nb_likes
# 0  BRqOEbUhxXV          _gaiotti_           0      393
# 271
#      shortcode influencer_profile nb_comments nb_likes
# 0  BUCwWwvlk1S          _gaiotti_           5      282
# 272
#      shortcode influencer_profile nb_comments nb_likes
# 0  BJx2Z2rBeWE     _geheimnisvoll           3     2284
# 273
#      shortcode influencer_profile nb_comments nb_likes
# 0  BKS-mhIhwhr     _geheimnisvoll           1     2044
# 274
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqN9A1PhHRe   _getyourprettyon           1      218
# 275
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrVF4KIB4mj   _getyourprettyon          57      382
# 276
#      shortcode influencer_profile nb_comments nb_likes
# 0  BYYP7sbhH6j         _gol.goli_          85     2766
# 277
#      shortcode influencer_profile nb_comments nb_likes
# 0  BiZDdp0AhwG           _greta_g           5       49
# 278
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjpM2ULhFJT           _greta_g           3       60
# 279
#     shortcode influencer_profile nb_comments nb_likes
# 0  iXquVJmR82            _gunter           0        5
# 280
#     shortcode influencer_profile nb_comments nb_likes
# 0  oAYV52mR2I            _gunter           0        9
# 281
#     shortcode influencer_profile nb_comments nb_likes
# 0  wNYeiomR94            _gunter           2       13
# 282
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXU60dXhALb     _hanna_bohman_          14      482
# 283
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnzZ8gBH65v      _harrietemily           5      360
# 284
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bicn3bMFb-U           her.must           1      572
# 285
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkgUJqkFIGR           her.must          25      876
# 286
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvMyVv8AdLx           her.must          27     2694
# 287
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfT59qEjavF  _hollygoeslightly           6      147
# 288
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhI6ynuBhwn  _hollygoeslightly          41      114
# 289
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bi1DbqRhsPi  _hollygoeslightly          53      191
# 290
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqTCVgEHv3W  _holly_patterson_          20      384
# 291
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrxiEtaHGBM  _holly_patterson_          13      364
# 292
#      shortcode influencer_profile nb_comments nb_likes
# 0  BluYDFng9Nh        _homebirds_          42      593
# 293
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnX_kKZgkPv        _homebirds_          44     1323
# 294
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpxPwUbl9Vf        _homebirds_          76      729
# 295
#      shortcode    influencer_profile nb_comments nb_likes
# 0  BomjvB4h0D7  _honeybunchesofoaks_          44     3133
# 296
#      shortcode    influencer_profile nb_comments nb_likes
# 0  BsJgtABFZeq  _honeybunchesofoaks_          29     2387
# 297
#      shortcode    influencer_profile nb_comments nb_likes
# 0  BvMbx5GA9mu  _honeybunchesofoaks_          25     1328
# 298
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br_z-ClAj6s          _hookitup           1       23
# 299
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvRwP6ugaqa          _hookitup           1       23
# 300
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvXYJ8TAlL_          _hookitup          11       83
# 301
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrsB78rAVma         _housewise           5      674
# 302
#      shortcode influencer_profile nb_comments nb_likes
# 0  BQVKHvtFqgO            _isifit           7      206
# 303
#      shortcode influencer_profile nb_comments nb_likes
# 0  BFtLIxHCV29            _ixenia           5      288
# 304
#      shortcode influencer_profile nb_comments nb_likes
# 0  BGURgmpiVzH            _ixenia           6      254
# 305
#      shortcode influencer_profile nb_comments nb_likes
# 0  BbSUIFilcpT       _jackfowler_           3      743
# 306
#      shortcode influencer_profile nb_comments nb_likes
# 0  Buozg6LlSU2       _jackfowler_        3596   137204
# 307
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqbxTR7H0u2      _jacksjournal           1      179
# 308
#     shortcode influencer_profile nb_comments nb_likes
# 0  vH5DMOoIwO               _jcl           2        9
# 309
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmlrHvgHQOk            _jefame          76      843
# 310
#      shortcode influencer_profile nb_comments nb_likes
# 0  BotOgZyj-MY          _jenstyle          45      305
# 311
#      shortcode influencer_profile nb_comments nb_likes
# 0  Blu9X3ejtYI       _jessicaskye         118      912
# 312
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bo9sl1whO-t       _jessicaskye         124     1339
# 313
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvG5xJlBlqA       _jessicaskye          59      889
# 314
#      shortcode influencer_profile nb_comments nb_likes
# 0  BaZa8ZylLHf     _jessica_reis_           9     1883
# 315
#      shortcode influencer_profile nb_comments nb_likes
# 0  Baejn8wFDug     _jessica_reis_           9     1884
# 316
#      shortcode influencer_profile nb_comments nb_likes
# 0  BbSOxxblqGy     _jessica_reis_          15     1371
# 317
#      shortcode influencer_profile nb_comments nb_likes
# 0  BopP1hZlAmt     _jessica_reis_          62     4300
# 318
#      shortcode influencer_profile nb_comments nb_likes
# 0  BniycdolIPi       _johnjarrett           8      163
# 319
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqB-ioglbo8     _jonasnordberg           4      574
# 320
#     shortcode influencer_profile nb_comments nb_likes
# 0  70XC3DiYuv     _julienlacroix          18      889
# 321
#      shortcode influencer_profile nb_comments nb_likes
# 0  BWQKgzUFl3e       _katiemeehan           6      229
# 322
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlBIBS7hoby  _kayleemccullough           1      160
# 323
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqnFf8uHaWx  _kayleemccullough           9      297
# 324
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrvrvL4nCS_  _kayleemccullough          10      167
# 325
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfuZnRhH7Of            _kellyu         149     2972
# 326
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkR5SaWBCiS             _kriku           0      349
# 327
#      shortcode influencer_profile nb_comments nb_likes
# 0  BS3iZQygEd0        _lady.ruby_           0       31
# 328
#      shortcode influencer_profile nb_comments nb_likes
# 0  BbXTam2n6Mv      _ladycamilla_           1       54
# 329
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvtXPwqHYiA      _ladycamilla_          27      208
# 330
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bei_no_B6HH     _ladyeatsalot_          13      370
# 331
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl2mvYGBzzm     _ladyeatsalot_           9      843
# 332
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bo92_E5g0uR     _ladyeatsalot_          18     1037
# 333
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhKTijEniN3           _lahrin_          65     1098
# 334
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnzH1ScHjY2          _lailaspa           6       69
# 335
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlrsN3Wljya          _lajanee_           2       61
# 336
#     shortcode influencer_profile nb_comments nb_likes
# 0  1eiyZjB6cs      _laurenestes_           7      385
# 337
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmKacfFlGyp          _linadoll          27     1899
# 338
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bv3C0Xthh6U          _linadoll           8     2397
# 339
#      shortcode influencer_profile nb_comments nb_likes
# 0  BxOmGkADMo9          _linadoll          19     2335
# 340
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsOBLJchcWT            _lineup           0       86
# 341
#      shortcode influencer_profile nb_comments nb_likes
# 0  BJQiTVDjPuk           _lisang_           2      474
# 342
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bpd565YFlzs    _littlesnippets           7      221
# 343
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsXWegdlQNr    _littlesnippets          29      216
# 344
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvMwY2qggo_           _louigi_          25     1638
# 345
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpSFG9FAuFX      _lustforlife_          13      449
# 346
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrcKiJyAIoJ         _lydiawong           0      358
# 347
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bst2LtBlx9M         _lydiawong           0      635
# 348
#      shortcode influencer_profile nb_comments nb_likes
# 0  BeDfQAUhJvI     _mackenziebay_         174     1211
# 349
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkXq--0nJMd     _mackenziebay_          90     1426
# 350
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmpSV3gl49L       _madewithjoy          49      470
# 351
#      shortcode influencer_profile nb_comments nb_likes
# 0  BurXJHwlGWy     _mariadepineda           7      308
# 352
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoZRLiADNGv     _marinakamura_           4     1035
# 353
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmGPbb2hNwx       _martinarao_           3      101
# 354
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjKW5dpHq9F          _maryglow           1      506
# 355
#      shortcode influencer_profile nb_comments nb_likes
# 0  BV30SQbAZKK    _micheleschmidt           3      447
# 356
#      shortcode influencer_profile nb_comments nb_likes
# 0  BaCathhgRuo    _micheleschmidt          26      898
# 357
#      shortcode influencer_profile nb_comments nb_likes
# 0  BMkQW2SBOIt  _michellecrawford           4      305
# 358
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZihimeHggI  _michellecrawford           7      537
# 359
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmNIxvAnNl2  _michellecrawford          18      486
# 360
#      shortcode      influencer_profile nb_comments nb_likes
# 0  BRgpjczh2Qc  _michelleforpresident_           1       85
# 361
#      shortcode      influencer_profile nb_comments nb_likes
# 0  BjDMlZNgzoc  _michelleforpresident_           3      108
# 362
#      shortcode influencer_profile nb_comments nb_likes
# 0  Boj6MRSgN_Z    _mihirjariwala_           4      822
# 363
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bqcql2rg57i    _mihirjariwala_           2      721
# 364
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhE_wF4n5LQ        _millergrey          33      551
# 365
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bh7EachARTu        _millergrey           8      456
# 366
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoEbg2tgImr        _millergrey          11      223
# 367
#      shortcode influencer_profile nb_comments nb_likes
# 0  BdAD_ljliQJ            _minoes          73      425
# 368
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpjkdZyHiqz      _missbroccoli          46      174
# 369
#      shortcode influencer_profile nb_comments nb_likes
# 0  BmYukB7lWmh      _mllexceline_          31      227
# 370
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bm6N0uHlWiP      _mllexceline_          40      202
# 371
#      shortcode influencer_profile nb_comments nb_likes
# 0  BSXUO8fh4ZF              _mngx           4       97
# 372
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoJuYmFhjey           _moda_md           2      132
# 373
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpFPmjsB4_l           _moda_md           2      189
# 374
#     shortcode influencer_profile nb_comments nb_likes
# 0  5nUY5cgrjj        _mollypayne           7      882
# 375
#      shortcode influencer_profile nb_comments nb_likes
# 0  BG2Xzm7ArpC        _mollypayne           1      462
# 376
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bb0ghdnntG3    _moniquecoleman          81    13548
# 377
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bs71VtIlRlY    _mosthypedshoes           2      118
# 378
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqDVLQ4Bo8T      ourfamilynest          46     5319
# 379
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bt2l_ORhffm        _mymycracra          96     3472
# 380
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bo24K1IjhGq     _namikanemoto_           1      345
# 381
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXYBevZFye1    _nathaliemartin          85     2001
# 382
#      shortcode influencer_profile nb_comments nb_likes
# 0  BaOm210ldV-    _nathaliemartin          63     1964
# 383
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br0l5FFnYey       _neil_lester           0      984
# 384
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsW2txHndgh       _nina_garcia           1       30
# 385
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bl-003uAQnx            _nonsky         138      852
# 386
#      shortcode influencer_profile nb_comments nb_likes
# 0  BiPzr9rn0sz           _paigeyx          20      681
# 387
#      shortcode   influencer_profile nb_comments nb_likes
# 0  Br2ovqtltAb  _parisiennedeparis_          31     1325
# 388
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZiYMRQFX1j      _pommegranate          65     1845
# 389
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhG27nzlz58    _queenofthering          28      214
# 390
#      shortcode influencer_profile nb_comments nb_likes
# 0  BCqbhf5g0tL      _rachelsander          10      614
# 391
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjaMUELDteq     _rebeccajaynee          67      328
# 392
#      shortcode influencer_profile nb_comments nb_likes
# 0  BusyHpvhgOo     _rebeccajaynee          69      292
# 393
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsA4QvNgmgS       _riccamilla_           0      245
# 394
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtEViNagEtd       _riccamilla_           0      203
# 395
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXlFXhrhL6k        _rossilino_          44     3316
# 396
#      shortcode influencer_profile nb_comments nb_likes
# 0  BfWTIl0hz_p        _rossilino_          96     6606
# 397
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bht5W0YHUaX   _sailormoon_love          47     1420
# 398
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bi0Dp5fnZZI   _sailormoon_love           2      743
# 399
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjDzYDpnhfg   _sailormoon_love          23     1204
# 400
#      shortcode influencer_profile nb_comments nb_likes
# 0  BPyRcVVh4-o          _sallyjo_           4     2268
# 401
#      shortcode influencer_profile nb_comments nb_likes
# 0  BVKqo5QA6Si          _sallyjo_          17     3503
# 402
#      shortcode influencer_profile nb_comments nb_likes
# 0  BkREndMH7o8  _samanthafletcher          31      277
# 403
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnCzjX4npTN  _samanthafletcher          12      222
# 404
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrMEs_hlDoN  _samanthafletcher          27      182
# 405
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br73ZuPlKHQ  _samanthafletcher          10      274
# 406
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtWOPcIlehc  _samanthafletcher          22      233
# 407
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnospVnFOAq        _sarahcurls          30      451
# 408
#      shortcode influencer_profile nb_comments nb_likes
# 0  BNIhaITg9qa        _sarapward_          34      505
# 409
#      shortcode influencer_profile nb_comments nb_likes
# 0  BQhVK7rA7nt        _sarapward_          30      427
# 410
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhsmUneDOEM        _sarapward_         121     1344
# 411
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnsM5AsFdLq        _sarapward_          39      677
# 412
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bhrtp0EnSZL     _shannonnicole          39     7953
# 413
#      shortcode influencer_profile nb_comments nb_likes
# 0  BhwoHHdnnaA     _shannonnicole          26     4437
# 414
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjHygBlhhWV     _shannonnicole          42     5870
# 415
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpuS_Tnnagn     _shannonnicole          34     4793
# 416
#      shortcode influencer_profile nb_comments nb_likes
# 0  BwprMyDFizl     _shannonnicole          96     4934
# 417
#      shortcode influencer_profile nb_comments nb_likes
# 0  Blm303BFq6M       _silviaraga_          21      506
# 418
#      shortcode influencer_profile nb_comments nb_likes
# 0  BxSJTB7D2Zj       _silviaraga_          14      186
# 419
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bf_lhSbHj2M           _skylish           8      113
# 420
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrDnglrBm7s           _skylish           7      122
# 421
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXdnyolH_Bz         _so_serena           0      677
# 422
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjQb9UkHdmU         _sparnold_          18     1432
# 423
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvFOwFhAAKm         _sparnold_          10      920
# 424
#      shortcode influencer_profile nb_comments nb_likes
# 0  BY7DIPJASxS            _stepht           6       93
# 425
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bf2ffoQhOIb            _stepht           2       78
# 426
#      shortcode influencer_profile nb_comments nb_likes
# 0  BQik9rrF2IY       _sugardenny_          12     1194
# 427
#      shortcode influencer_profile nb_comments nb_likes
# 0  BvZTBwcAZvM       _summerella_         445    99569
# 428
#      shortcode influencer_profile nb_comments nb_likes
# 0  BZ1s3OUBOsk          _surrules          12      455
# 429
#      shortcode influencer_profile nb_comments nb_likes
# 0  BpkpKlQg4bF          _surrules          31      927
# 430
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuoarAdBK_J     lyaakifimtiyaz           0       27
# 431
#      shortcode influencer_profile nb_comments nb_likes
# 0  BAUbhtexZ9S          _sylwina_          11      278
# 432
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqotHd7hPhC          _sylwina_         116     3280
# 433
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtEm1qCFS-7     _taamiferreira          20      631
# 434
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrT_IFfnqSj          _tanyapop          11      134
# 435
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgYGED1BLYV     _tasteofstyle_          23      770
# 436
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bpy0b3XhOKE     _tasteofstyle_          14     1251
# 437
#      shortcode influencer_profile nb_comments nb_likes
# 0  Br2Syl2hZpO     _tasteofstyle_          20      631
# 438
#      shortcode influencer_profile nb_comments nb_likes
# 0  BusoCQPB_Vw     _tasteofstyle_          43      741
# 439
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqnET9pH2Id       _tauanasilva           1       65
# 440
#      shortcode influencer_profile nb_comments nb_likes
# 0  BdEEjWxnYWp    _taylor_michael          17      997
# 441
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bb8vHt0n2wg     _teganthevegan          35      465
# 442
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqgHSc-gD0M     _teganthevegan           7      103
# 443
#      shortcode influencer_profile nb_comments nb_likes
# 0  BSmh_vgBZh9    _thebrunetteone          10       85
# 444
#      shortcode    influencer_profile nb_comments nb_likes
# 0  BoJz-25Fnwu  _thegentlemanpirate_           0        8
# 445
#      shortcode influencer_profile nb_comments nb_likes
# 0  BgjS7VRgzi2   _theglitzysphere         114    12150
# 446
#      shortcode influencer_profile nb_comments nb_likes
# 0  BheU4zpgU6A   _theglitzysphere          71    10569
# 447
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bg6ouewlYnw  _thegypsygoddess_          18      267
# 448
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bn9Sd55Hukx  _thegypsygoddess_           9      129
# 449
#      shortcode influencer_profile nb_comments nb_likes
# 0  BsoEOc9ltPu  _thegypsygoddess_          15      160
# 450
#      shortcode influencer_profile nb_comments nb_likes
# 0  BraALQVlPvG     _themumdiaries           4       59
# 451
#     shortcode influencer_profile nb_comments nb_likes
# 0  iWaDUXyIyI       _theoliveoil           6       61
# 452
#     shortcode influencer_profile nb_comments nb_likes
# 0  rIGGU-yIye       _theoliveoil           2       36
# 453
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BjRCCu9D3Qj  _theseplantsofmine_           9      844
# 454
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BpwGWkag4-7  _theseplantsofmine_          12      312
# 455
#      shortcode influencer_profile nb_comments nb_likes
# 0  BXCzg6lAPuH      _thestylegen_           9      418
# 456
#      shortcode influencer_profile nb_comments nb_likes
# 0  BnF9Gw6hJsM        _thevanlife           1      705
# 457
#      shortcode influencer_profile nb_comments nb_likes
# 0  BqWhb9cF2nC        _thevanlife           9     1392
# 458
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bqk1X6-F0VI   _thewillow_tree_           6      151
# 459
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrGOJyRluY3   _thewillow_tree_           7      228
# 460
#      shortcode influencer_profile nb_comments nb_likes
# 0  BeJqQw0hiU-       _the_b_word_         128     2432
# 461
#      shortcode influencer_profile nb_comments nb_likes
# 0  BrNY1oMAt29   _thingsfor_girls          21      896
# 462
#      shortcode    influencer_profile nb_comments nb_likes
# 0  BsQSeFMFhtu  _thisgirlcanorganise          78     1729
# 463
#      shortcode        influencer_profile nb_comments nb_likes
# 0  BoYmvhHBbMb  _this_sweet_life_of_mine         136      339
# 464
#      shortcode        influencer_profile nb_comments nb_likes
# 0  Bp2fmH9gDnu  _this_sweet_life_of_mine         130      313
# 465
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bse_et2g-Y9          _tomomi18           9      860
# 466
#      shortcode influencer_profile nb_comments nb_likes
# 0  BlaAc6dgA9i         _tonyflynn          77     1038
# 467
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BfhPtD_jUQ5  _trishamarieditton_           3      139
# 468
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BuCw3UdAqD3  _trishamarieditton_           4      106
# 469
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bga7G6glG0d         _trtzmedia           1      164
# 470
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bnj41jTB3sG           _tunalee           0       44
# 471
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuIQOsjF0Ue           _tunalee           4       60
# 472
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bpwq16gHfVO            _u.rim_           6      175
# 473
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bj7eUXal_BT            _urvee_          17      352
# 474
#      shortcode influencer_profile nb_comments nb_likes
# 0  BphMidQAa1v            _urvee_          17      339
# 475
#      shortcode influencer_profile nb_comments nb_likes
# 0  BoT3icin5cy            _vanc__           0      158
# 476
#      shortcode  influencer_profile nb_comments nb_likes
# 0  BVFqRo5DvGT  _victoriagutierrez           1      233
# 477
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bk32P2xhjXn       _violetbanks           1       53
# 478
#      shortcode influencer_profile nb_comments nb_likes
# 0  BuP1YnQgVnl       _violetbanks           8      112
# 479
#      shortcode influencer_profile nb_comments nb_likes
# 0  BljPH91nQ_B          _wangover           5       43
# 480
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bq_KoyghrBg          _wangover           6      145
# 481
#      shortcode influencer_profile nb_comments nb_likes
# 0  BjcFBtWhj6C       _watchfreak_         123      426
# 482
#      shortcode influencer_profile nb_comments nb_likes
# 0  BtT6mXwHGtz       _watchfreak_          45      356
# 483
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BhY7RB_FXKl  _whiteafterlaborday          86     3536
# 484
#      shortcode   influencer_profile nb_comments nb_likes
# 0  Bp9zuq-HAcs  _whiteafterlaborday          33     4492
# 485
#      shortcode   influencer_profile nb_comments nb_likes
# 0  BuEjVL2AEFZ  _whiteafterlaborday          48     6166
# 486
#      shortcode influencer_profile nb_comments nb_likes
# 0  Bb265G7BMgM          _wildfern          20     4642

# %%
# Export dataframe as csv
post_table.to_csv(r'D:\Influencer_Projekt\post_table.csv')
